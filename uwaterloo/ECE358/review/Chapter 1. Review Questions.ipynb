# %% [markdown]
# # Review Questions from Chapter 1
#
# 1. **What is the Internet?**
#     - The Internet is a computer network that interconnects hundreds of millions of computing devices throughout the world.
#
#
# 2. **What is a communication protocol?**
#     - A protocol defines the format and the order of messages exchanged among communicating entities, as well as actions taken on the message transmission and receipt
#
#
# 3. **What is a local area network (LAN) and what is a wireless LAN (WLAN)?**
#     - LAN is a computer network that interconnects computers within a limited area such as a residence, school, or office building.
#     - A wireless LAN is a LAN that is interconnected using wireless links
#
#
# 4. **What is an *access network* and what is a *core network*?**
#     - *Access Network*: the network that physically connects an end system to the first router (also known as the "edge router") on a path from the end system to any other distant end system.
#     - "Core Network": The mesh of packet swicthes and links that interconnects the Internet's end systems.
#
# Access Network | Core Network
# ---|---
# <img src="../img/Snip20191014_157.png"/>|<img src="../img/Snip20191014_158.png"/>
#
#
# 5. **What is circuit switching? Explain its advantages and disadvantages.**
#     - In circuit-switched networks, the resources needed along a path (buffers, link transmission rate) to provide for communication between the end systems are **reserved** for the duration of the communication session between end systems.
#
#
# 6. **How is circuit switching implemented?**
#     - A circuit in a link is implemented with either **frequency-division multiplexing (FDM)** or **time-division multiplexing (TDM)**.
#         - with **FDM**, the frequency spectrum of a link is divided up among the connections established across the link, and the link dedicates a frequency band to each connection for the duration of the connection
#         -  with **TDM**, time is divided into frames of fixed duration, and each frame is divided into a fixed number of time slots; when the network establishes a connection across a link, the network dedicates one time slot in every frame to this connection
#
# FDM|TDM
# ---|---
# <img src="../img/Snip20191014_159.png"/>|<img src="../img/Snip20191014_160.png"/>
#
#
# 7. **What is meant by "circuit-like behavior" of a computer network?**
#     - guaranteed (constant) performance in transmission rate and delay
#
#
# 8. **What is meant by resource reservation in a circuit switched network?**
#     - The dedicated circuits are idle during *silent periods*, when one connection is idle and not actively using the link for transmission, its resources (frequency bands or time slots in the links along the connection's route) cannot be used by other ongoing connections.
#
#
# 9. **Name some key resources in a circuit switched network.**
#     - frequency bands in FDM (in the links along the connection's route)
#     - time slots in TDM (in the links along the connection's route)
#
#
# 10. **What is packet switching? Explain its advantages and disadvantages.**
#     - To send a message from a source end system to a destination end system, the source breaks long messages into smaller chunks of data known as **packets**
#     - between source and destination, each packet travels through communication links and **packet switches** (routers and link-layer switches)
#     - packets are transmitted over each communication link at a rate equal to the *full* transmission rate of the link ($t_{trans}=L/R$)
#
#
# 11. **Compare circuit switching with packet switching.**
#     - Circuit switching can guarantee constant transmission rate (performance), but the fact that it reserves resources for connections even though the reserved resource can be sometimes idle means that the link support less users.
#     - Packet switching allows more users to use the network because it does not require resources to be reserved for connections. Packet swicthing also allows for bursty data as resources are shared among all connections and it means one connection can leverage more resources when it needs. However, it gives rise to potential excessive congestion that lead to packet delay and loss, which is then needed to be resolved with protocols that provide reliable data transfer and congestion control.
#
#
# 12. **Explain the concept of "store-and-forward" in packet switching.**
#     - The packet switch must receive the entire packet before it can begin transmit the first bit of the packet onto the outbound link.
# <img src="../img/Snip20191014_161.png" width=60%/>
#
#
# 13. **Identify and explain some key hardware components of the Internet.**
#     - Connected Computing Devices
#         - host end systems running network apps
#     - Communication Links
#         - fiber, copper, radio, satellite
#     - Packet Switches
#         - routers and switches
#
#
# 14. **What are Tier-1, Regional ISPs, and Access ISP networks?**
#     - Access ISP: End systems connect to the Internet via access ISP network. Access ISP can provide either wired or wireless connection to Tier 1 ISP, IXP, or Regional ISP.
#     - Regional ISP: In a given region, there may exist regional ISP to which all the access networks in the region connect.
#     - Tier-1: Tier 1 ISP is an ISP that has access to the entire Internet Region solely via its free and reciprocal peering agreements, and it doesn't pay transit fees to anyone to reach any destination in the Internet Region。
#
#
# 15. **What is a broadcast link and what is a point-to-point link?**
#     - Point-to-point link
#         - consists of a single sender at one end of the link and a single receiver at the other end of the link
#     - Broadcast link
#         - can have multiple sending and receiving nodes all connected to the same, single, shared broadcast channel
#
#
# 16. **What is a router?**
#     - Router is a type of packet switches, it forward packets toward their destination.
#     - Routers are typically used in the network core.
#
#
# 17. **What are two performance characteristics of a network link?**
#     - transmission rate and length
#
#
# 18. **Identify and explain four sources of packet delay in a packet switched network.**
#     - Processing Delay: the time required to examine the packet's header and determine where to direct the packet + the time needed to check for bit-level errors in the packet + etc.
#     - Queuing Delay: the packet waits to be transmiitted onto the link, the duration of which depends on the queue intensity
#     - Transmission Delay: $L/R$, the amount of time required to push all of the packet's bits into the link
#     - Propagation Delay: the time required to propagate from the beginning of the link to the next router
#
#
# 19. **Out of the four sources of packet delays, what are the most  deterministic and what are highly variable?**
#     - the most determinitsic: processing delay
#     - highly variable: queuing delay
#
#
# 20. **Identify three performance characteristics of end-to-end communication between two host computers.**
#     - delay, packet loss, throughput
#
#
# 21. **Explain the difference between transmission delay and propagation delay in computer networks.**
#     - transmission delay is the time required to push all of the packet's bits into the link
#     - propagation delay is the time required for the bit to travel from one router to another
#
#
# 22. **Explain how queuing delay changes with traffic intensity.**
#     - when traffic intensity is high, there is a lot of packets arriving at the router and the queue will be more busy, the queuing delay will then be higher
#
#
# 23. **Give an outline of a procedure to measure end-to-end delay between a client computer and a server machine.**
#     -
#
#
# 24. **Why are (data) packets lost in a computer network?**
#     - ???
#
#
# 25. **Why are correctly received data packets occasionally dropped by routers?**
#     - in reality a queue preceding a link has finite capacity, so when a packet arrive to find a full queue, the router will **drop** the packet and the packet will be *lost*.
#
#
# 26. **What better features can an expensive router have compared to a low cost router?**
#     - it can have a longer packet queue for packet switching, thus reducing the probability of a packet loss
#     - for a WLAN router, it can implement optional function like PCF
#
#
# 27. **What are throughput, instantaneous throughput, and average throughput?**
#     - Throughput: rate at which bits are transferred between sender/receiver
#     - Instantaneous Throughput: the rate at any instant of time at which receiving host is receiving the message
#     - Average Throughpt: the average transfer rate at which the receiving host is receiving the message
#
#
# 28. **What is bottleneck bandwidth?**
#     - in a connection made of many links, the bottleneck link is the link on end-end path that constrains the end-end throughput (likely with the smallest throughput)
#
#
# 29. **Why are network protocols organized in a layered fashion on hosts and routers?**
#     - to deal with complex systems
#         - modulation eases maintenance, updating of system, since change of implementation of a layer's service is transparent to the rest of the system
#         - explicit structure
#
#
# 30. **Briefly explain the Internet protocol stack**
#     - the Internet protocol stack is composed of 5 layers, each layer implement a service via its own internal-layer actions, relying on services provided by layer below
#         - application: supporting network applications (software), e.g., FTP, SMTP, HTTP
#         - transport: process-process data transfer (software), e.g., TCP, UDP
#         - network: routing of datagrams from source to destination (software & hardware), e.g., IP, routing protocols
#         - link: data transfer between neighboring network elements (hardware), e.g., Ethernet, WiFi
#         - physical: bits on the wire (hardware)
#
#
# 31. **Briefly explain the ISO/OSI reference model.**
#     - application
#     - **presentation**: allow applications to interpret meaning of data (e.g., encryption, compression, machine-specific conventions)
#     - **session**: synchronization, checkpointing, recovery of data exchange
#     - transport
#     - network
#     - link
#     - physical
#
#
# 32. **What is message encapsulation? Explain its advantages.**
#     - In general, message encapsulation in network means each layer encapsulate the message from its upper layer with additional header/trailer information for its own purpose.
#     - The main advantage is the modular design, which allows each layer to implement its own logic without leaking/exposing its own context to other layers.
#
#
# 33. **What is a side effect of encapsulation?**
#      - Overhead in messages
#
#
# 34. **What is 1-hop communication?**
#
#
# 35. **What is hop-by-hop, multi-hop communication?**
#
#
# 36. **Name one protocol from each category: one-hop communication, multi-hop communication, and end-to-end communication.**
#
#
# 37. **Give typical examples of link speeds - both wired and wireless - and bit error rates in computer networks.**
#
#
# 38. **What is an Internet Exchange Point (IXP)? How does it serve the end-users?**
